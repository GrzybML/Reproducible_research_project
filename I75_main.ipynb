# %% [markdown]
# # Analysis of I75 Dataset

# %%
import pandas as pd
from data_preprocessor import DataPreprocessor
from ML_classifier import MLClassifier
import csv
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
# Load data
I24_data = pd.read_csv('data/I75_data.csv', low_memory=False)
I24_data
# Out:
#         incident at sensor (i)    road  mile                    type
# 0                            1  00I75S  13.7  Suspected Minor Injury  \
# 1                            1  00I75S  13.7  Suspected Minor Injury
# 2                            1  00I75S  13.7  Suspected Minor Injury
# 3                            1  00I75S  13.7  Suspected Minor Injury
# 4                            1  00I75S  13.7  Suspected Minor Injury
# ...                        ...     ...   ...                     ...
# 189901                       0  00I75S   2.1                     NaN
# 189902                       0  00I75S   2.1                     NaN
# 189903                       0  00I75S   2.1                     NaN
# 189904                       0  00I75S   2.1                     NaN
# 189905                       0  00I75S   2.1                     NaN
#
#               date incident_time  incident_hour data_time weather     light
# ...
