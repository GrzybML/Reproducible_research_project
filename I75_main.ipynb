# %% [markdown]
# # Analysis of I75 Dataset

# %%
import pandas as pd
from data_preprocessor import DataPreprocessor
from ML_classifier import MLClassifier
import csv
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
# Load data
I75_data = pd.read_csv('data/I75_data.csv', low_memory=False)
I75_data.head()
# Out:
#    incident at sensor (i)    road  mile                    type        date
# 0                       1  00I75S  13.7  Suspected Minor Injury  2020-12-09  \
# 1                       1  00I75S  13.7  Suspected Minor Injury  2020-12-09
# 2                       1  00I75S  13.7  Suspected Minor Injury  2020-12-09
# 3                       1  00I75S  13.7  Suspected Minor Injury  2020-12-09
# 4                       1  00I75S  13.7  Suspected Minor Injury  2020-12-09
#
#   incident_time  incident_hour data_time weather     light  ...
# 0         14:57             14  14:42:00      --  Daylight  ...  \
# 1         14:57             14  14:42:30      --  Daylight  ...
# 2         14:57             14  14:43:00      --  Daylight  ...
# 3         14:57             14  14:43:30      --  Daylight  ...
# 4         14:57             14  14:44:00      --  Daylight  ...
#
#    occupancy (i+2)  speed (i+3)  volume (i+3)  occupancy (i+3)  speed (i+4)
# 0              9.0    62.250000           9.0             3.50    41.666667  \
# 1             10.5    64.000000          10.0             3.75    43.333333
# 2              7.0    58.000000           4.0             1.75    43.333333
# 3              9.0    62.750000           7.0             2.25    43.333333
# 4              6.5    60.333333          10.0             5.50    46.000000
#
#    volume (i+4)  occupancy (i+4)  speed (i+5)  volume (i+5)  occupancy (i+5)
# 0           9.0             3.75          NaN           NaN              NaN
# 1          12.0             8.00          NaN           NaN              NaN
# 2          12.0             6.00          NaN           NaN              NaN
# 3           8.0             4.75          NaN           NaN              NaN
# 4          23.0            10.75          NaN           NaN              NaN
#
# [5 rows x 43 columns]

# %% [markdown]
# ## Variables type conversion

# %%
# Convert types of 'date' and 'incident_time'
I75_data['date'] = pd.to_datetime(I75_data['date'])
I75_data['incident_time'] = pd.to_datetime(I75_data['date'].dt.strftime('%Y-%m-%d') + ' ' + I75_data['incident_time'], format='%Y-%m-%d %H:%M')

# Adjust `data_time` for potential rollover to the next or previous day
def adjust_observation_time(row):
    data_time = pd.to_datetime(row['date'].strftime('%Y-%m-%d') + ' ' + row['data_time'], format='%Y-%m-%d %H:%M:%S')
    if data_time < row['incident_time'] - pd.Timedelta(hours=12):
        data_time += pd.Timedelta(days=1)
    elif data_time > row['incident_time'] + pd.Timedelta(hours=12):
        data_time -= pd.Timedelta(days=1)
    return data_time

I75_data['data_time'] = I75_data.apply(adjust_observation_time, axis=1)

# %% [markdown]
# ## Filtering the dataset

# %%
# Calculate the time difference in minutes
I75_data['time_diff'] = (I75_data['data_time'] - I75_data['incident_time']).dt.total_seconds() / 60

# Filter data for observations from 4 min before up to 7 min after an accident/non-accident
filtered_I75_data = I75_data[(I75_data['time_diff'] >= -4) & (I75_data['time_diff'] <= 7)]

# Delete unnecessary variables 
filtered_I75_data = filtered_I75_data.drop(columns=['road', 'mile', 'type', 'date', 'incident_time', 'incident_hour', 'data_time'])
filtered_I75_data.head()
# Out:
#     incident at sensor (i) weather     light  speed (i-5)  volume (i-5)
# 22                       1      --  Daylight         72.5          10.0  \
# 23                       1      --  Daylight         71.5           9.0
# 24                       1      --  Daylight         73.5           6.0
# 25                       1      --  Daylight         73.5          11.0
# 26                       1      --  Daylight         73.0           8.0
#
#     occupancy (i-5)  speed (i-4)  volume (i-4)  occupancy (i-4)  speed (i-3)
# 22              6.5         56.5          11.0              8.5         63.0  \
# 23              5.0         57.5           9.0              6.5         62.5
# 24              3.0         59.5          12.0              7.5         63.5
# 25              5.5         55.0          13.0             11.0         65.0
# 26              3.0         59.5          12.0              5.0         65.0
#
#     ...  speed (i+3)  volume (i+3)  occupancy (i+3)  speed (i+4)
# 22  ...    64.000000          15.0             4.50         22.0  \
# 23  ...    63.000000          19.0             6.25         21.5
# 24  ...    64.666667          12.0             5.50         32.0
# 25  ...    64.333333          11.0             5.00         27.5
# 26  ...    63.666667          16.0             7.00         33.0
#
#     volume (i+4)  occupancy (i+4)  speed (i+5)  volume (i+5)  occupancy (i+5)
# 22           5.0            28.75          NaN           NaN              NaN  \
# 23           8.0            49.25          NaN           NaN              NaN
# 24          19.0            41.00          NaN           NaN              NaN
# 25          14.0            34.50          NaN           NaN              NaN
# 26          11.0            31.75          NaN           NaN              NaN
#
#     time_diff
# 22       -4.0
# 23       -3.5
# 24       -3.0
# 25       -2.5
# 26       -2.0
#
# [5 rows x 37 columns]

# %%
# Adjust variables names
filtered_I75_data.rename(columns={'speed (i)': 'speed (i+0)'}, inplace=True)
filtered_I75_data.rename(columns={'volume (i)': 'volume (i+0)'}, inplace=True)
filtered_I75_data.rename(columns={'occupancy (i)': 'occupancy (i+0)'}, inplace=True)

# %% [markdown]
# ## Handling missing data

# %%
print(" \nCount total NaN at each column in a DataFrame : \n\n", filtered_I75_data.isnull().sum())
# Out:
#
# Count total NaN at each column in a DataFrame :
#
#  incident at sensor (i)        0
# weather                       0
# light                         0
# speed (i-5)               30084
# volume (i-5)              28281
# occupancy (i-5)           28281
# speed (i-4)               21605
# volume (i-4)               9192
# occupancy (i-4)            9192
# speed (i-3)                7026
# volume (i-3)               5530
# occupancy (i-3)            5530
# speed (i-2)                9693
# volume (i-2)               8041
# occupancy (i-2)            8041
# speed (i-1)                8137
# volume (i-1)               7258
# occupancy (i-1)            7258
# speed (i+0)               12173
# volume (i+0)              11391
# occupancy (i+0)           11391
# speed (i+1)                7690
# volume (i+1)               6308
# occupancy (i+1)            6308
# speed (i+2)               26046
# volume (i+2)              23807
# occupancy (i+2)           23807
# speed (i+3)                9873
# volume (i+3)               6637
# occupancy (i+3)            6637
# speed (i+4)               19638
# volume (i+4)              17514
# occupancy (i+4)           17514
# speed (i+5)               22220
# volume (i+5)              14466
# occupancy (i+5)           14466
# time_diff                     0
# dtype: int64

# %%
# Filtering out missing observations from 'i+0' sensor

filtered_I75_data = filtered_I75_data[filtered_I75_data['speed (i+0)'].notna()]
filtered_I75_data.head()
# Out:
#     incident at sensor (i) weather     light  speed (i-5)  volume (i-5)
# 22                       1      --  Daylight         72.5          10.0  \
# 24                       1      --  Daylight         73.5           6.0
# 25                       1      --  Daylight         73.5          11.0
# 26                       1      --  Daylight         73.0           8.0
# 27                       1      --  Daylight         72.5          11.0
#
#     occupancy (i-5)  speed (i-4)  volume (i-4)  occupancy (i-4)  speed (i-3)
# 22              6.5         56.5          11.0              8.5         63.0  \
# 24              3.0         59.5          12.0              7.5         63.5
# 25              5.5         55.0          13.0             11.0         65.0
# 26              3.0         59.5          12.0              5.0         65.0
# 27              5.0         60.0           8.0              4.5         64.0
#
#     ...  speed (i+3)  volume (i+3)  occupancy (i+3)  speed (i+4)
# 22  ...    64.000000          15.0              4.5         22.0  \
# 24  ...    64.666667          12.0              5.5         32.0
# 25  ...    64.333333          11.0              5.0         27.5
# 26  ...    63.666667          16.0              7.0         33.0
# 27  ...    66.500000           6.0              3.0         30.5
#
#     volume (i+4)  occupancy (i+4)  speed (i+5)  volume (i+5)  occupancy (i+5)
# 22           5.0            28.75          NaN           NaN              NaN  \
# 24          19.0            41.00          NaN           NaN              NaN
# 25          14.0            34.50          NaN           NaN              NaN
# 26          11.0            31.75          NaN           NaN              NaN
# 27           5.0            28.75          NaN           NaN              NaN
#
#     time_diff
# 22       -4.0
# 24       -3.0
# 25       -2.5
# 26       -2.0
# 27       -1.5
#
# [5 rows x 37 columns]

# %%
# Data Preprocessing
preprocessor = DataPreprocessor(filtered_I75_data)

preprocessor.replace_missings()
preprocessed_I75_data = preprocessor.get_preprocessed_data()

preprocessed_I75_data.head()
# Out:
#     incident at sensor (i) weather     light  speed (i-5)  volume (i-5)
# 22                       1      --  Daylight         72.5          10.0  \
# 24                       1      --  Daylight         73.5           6.0
# 25                       1      --  Daylight         73.5          11.0
# 26                       1      --  Daylight         73.0           8.0
# 27                       1      --  Daylight         72.5          11.0
#
#     occupancy (i-5)  speed (i-4)  volume (i-4)  occupancy (i-4)  speed (i-3)
# 22              6.5         56.5          11.0              8.5         63.0  \
# 24              3.0         59.5          12.0              7.5         63.5
# 25              5.5         55.0          13.0             11.0         65.0
# 26              3.0         59.5          12.0              5.0         65.0
# 27              5.0         60.0           8.0              4.5         64.0
#
#     ...  speed (i+3)  volume (i+3)  occupancy (i+3)  speed (i+4)
# 22  ...    64.000000          15.0              4.5         22.0  \
# 24  ...    64.666667          12.0              5.5         32.0
# 25  ...    64.333333          11.0              5.0         27.5
# 26  ...    63.666667          16.0              7.0         33.0
# 27  ...    66.500000           6.0              3.0         30.5
#
#     volume (i+4)  occupancy (i+4)  speed (i+5)  volume (i+5)  occupancy (i+5)
# 22           5.0            28.75    62.333333          15.0             5.25  \
# 24          19.0            41.00    62.333333          15.0             5.25
# 25          14.0            34.50    62.333333          15.0             5.25
# 26          11.0            31.75    62.333333          15.0             5.25
# 27           5.0            28.75    62.333333          15.0             5.25
#
#     time_diff
# 22       -4.0
# 24       -3.0
# 25       -2.5
# 26       -2.0
# 27       -1.5
#
# [5 rows x 37 columns]

# %%
# Creating ratio to handling imbalanced data
ratio = 24  
count = int(ratio * len(preprocessed_I75_data[preprocessed_I75_data['incident at sensor (i)'] == 1]))

preprocessed_I75_data = pd.concat([
    preprocessed_I75_data[preprocessed_I75_data['incident at sensor (i)'] == 1],  
    preprocessed_I75_data[preprocessed_I75_data['incident at sensor (i)'] == 0].sample(n=count, random_state=42)  
])

preprocessed_I75_data['incident at sensor (i)'].value_counts()
# Out:
# incident at sensor (i)
# 0    10752
# 1      448
# Name: count, dtype: int64

# %% [markdown]
# ## One-hot encoding variables

# %%
# Data Preprocessing
preprocessor = DataPreprocessor(preprocessed_I75_data)

preprocessor.one_hot_encode()
preprocessed_I75_data = preprocessor.get_preprocessed_data()
preprocessed_I75_data.head()
# Out:
#     incident at sensor (i)  speed (i-5)  volume (i-5)  occupancy (i-5)
# 22                       1         72.5          10.0              6.5  \
# 24                       1         73.5           6.0              3.0
# 25                       1         73.5          11.0              5.5
# 26                       1         73.0           8.0              3.0
# 27                       1         72.5          11.0              5.0
#
#     speed (i-4)  volume (i-4)  occupancy (i-4)  speed (i-3)  volume (i-3)
# 22         56.5          11.0              8.5         63.0          15.0  \
# 24         59.5          12.0              7.5         63.5           8.0
# 25         55.0          13.0             11.0         65.0           5.0
# 26         59.5          12.0              5.0         65.0          12.0
# 27         60.0           8.0              4.5         64.0          12.0
#
#     occupancy (i-3)  ...  volume (i+4)  occupancy (i+4)  speed (i+5)
# 22             11.5  ...           5.0            28.75    62.333333  \
# 24              5.5  ...          19.0            41.00    62.333333
# 25              4.0  ...          14.0            34.50    62.333333
# 26              7.0  ...          11.0            31.75    62.333333
# 27             10.5  ...           5.0            28.75    62.333333
#
#     volume (i+5)  occupancy (i+5)  time_diff  weather_Rain  weather_Snow
# 22          15.0             5.25       -4.0         False         False  \
# 24          15.0             5.25       -3.0         False         False
# 25          15.0             5.25       -2.5         False         False
# 26          15.0             5.25       -2.0         False         False
# 27          15.0             5.25       -1.5         False         False
#
#     light_Dawn  light_Daylight
# 22       False            True
# 24       False            True
# 25       False            True
# 26       False            True
# 27       False            True
#
# [5 rows x 39 columns]

# %%
# Save preprocessed data
preprocessed_I75_data.to_csv('data/preprocessed_I75_data.csv', index=False)

# %% [markdown]
# # Modelling steps

# %%
# classifier = MLClassifier(data=preprocessed_I75_data, target='incident at sensor (i)')
# classifier.train_models()

# %%
#classifier.generate_heatmap(results, 'DR', 1) ### incorrect heatmap code

import output as ou

ou.output(preprocessed_I75_data)
# Out:
# `use_label_encoder` is deprecated in 1.7.0.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# ...
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# The max_iter was reached which means the coef_ did not converge
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 5
#       1 #classifier.generate_heatmap(results, 'DR', 1)
#       3 import output as ou
# ----> 5 ou.output(preprocessed_I75_data)
#
# File c:\Users\olekw\Desktop\Studia\MAG 2 - WNE\9.RR\_final\Reproducible_research_project\output.py:34, in output(data)
#      31 classifier.generate_heatmap(results, 'AUC-PR', setting=2)
#      33 #SHAP plot values
# ---> 34 classifier.plot_shap_values(model_name='XGBoost')
#      36 #Summary table
#      37 df_summary = classifier.generate_summary_table(results)
#
# File c:\Users\olekw\Desktop\Studia\MAG 2 - WNE\9.RR\_final\Reproducible_research_project\ML_classifier.py:146, in MLClassifier.plot_shap_values(self, model_name)
#     143 model = self.models[model_name]
#     144 model.fit(X_train, y_train)
# --> 146 explainer = shap.Explainer(model, X_train)
#     147 shap_values = explainer(X_train)
#     149 plt.figure(figsize=(10, 6))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\shap\explainers\_explainer.py:185, in Explainer.__init__(self, model, masker, link, algorithm, output_names, feature_names, linearize_link, seed, **kwargs)
#     183 elif algorithm == "tree":
#     184     self.__class__ = explainers.TreeExplainer
# --> 185     explainers.TreeExplainer.__init__(self, self.model, self.masker, link=self.link, feature_names=self.feature_names, linearize_link=linearize_link, **kwargs)
#     186 elif algorithm == "additive":
#     187     self.__class__ = explainers.AdditiveExplainer
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\shap\explainers\_tree.py:166, in TreeExplainer.__init__(self, model, data, model_output, feature_perturbation, feature_names, approximate, **deprecated_options)
#     164 self.feature_perturbation = feature_perturbation
#     165 self.expected_value = None
# --> 166 self.model = TreeEnsemble(model, self.data, self.data_missing, model_output)
#     167 self.model_output = model_output
#     168 #self.model_output = self.model.model_output # this allows the TreeEnsemble to translate model outputs types by how it loads the model
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\shap\explainers\_tree.py:976, in TreeEnsemble.__init__(self, model, data, data_missing, model_output)
#     974 self.original_model = model.get_booster()
#     975 xgb_loader = XGBTreeModelLoader(self.original_model)
# --> 976 self.trees = xgb_loader.get_trees(data=data, data_missing=data_missing)
#     977 self.base_offset = xgb_loader.base_score
#     978 self.objective = objective_name_map.get(xgb_loader.name_obj, None)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\shap\explainers\_tree.py:1783, in XGBTreeModelLoader.get_trees(self, data, data_missing)
#    1780             self.values[i,j] = self.node_info[i][j]
#    1782     l = len(self.node_cleft[i])
# -> 1783     trees.append(SingleTree({
#    1784         "children_left": self.node_cleft[i],
#    1785         "children_right": self.node_cright[i],
#    1786         "children_default": self.children_default[i,:l],
#    1787         "feature": self.features[i,:l],
#    1788         "threshold": self.thresholds[i,:l],
#    1789         "value": self.values[i,:l],
#    1790         "node_sample_weight": self.sum_hess[i]
#    1791     }, data=data, data_missing=data_missing))
#    1792 return trees
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\shap\explainers\_tree.py:1609, in SingleTree.__init__(self, tree, normalize, scaling, data, data_missing)
#    1607 if data is not None and data_missing is not None:
#    1608     self.node_sample_weight.fill(0.0)
# -> 1609     _cext.dense_tree_update_weights(
#    1610         self.children_left, self.children_right, self.children_default, self.features,
#    1611         self.thresholds, self.values, 1, self.node_sample_weight, data, data_missing
#    1612     )
#    1614 # we compute the expectations to make sure they follow the SHAP logic
#    1615 self.max_depth = _cext.compute_expectations(
#    1616     self.children_left, self.children_right, self.node_sample_weight,
#    1617     self.values
#    1618 )
#
# TypeError: Cannot cast array data from dtype('O') to dtype('float64') according to the rule 'safe'
